# %%
l=[1,'py',[3,4],True,10.4,11,['sql',45]]
print(l[2].pop(0))
print(l)
print(l[-1].remove(45))
print(l)
# Out:
# 3
# [1, 'py', [4], True, 10.4, 11, ['sql', 45]]
# None
# [1, 'py', [4], True, 10.4, 11, ['sql']]

# %%
a=256 
b=256
print(a is b)
# Out:
# True

# %%
print({} and True)
# Out:
# {}

# %%
l=[i**2 for i in range(1,10)]
print(l)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
print(chr(65))
# Out:
# A

# %%
l=[1,'py',[3,4],True,10.4,11]
i=0
while i<len(l):
    print(l[i])
    i+=1
# Out:
# 1
# py
# [3, 4]
# True
# 10.4
# 11

# %%
l=[10,5,[1,3],4]
print(l.index([1,3]))
# Out:
# 2

# %%
l=[10,5,[1,3],4]
l[2].sort()
print(l)
# Out:
# [10, 5, [1, 3], 4]

# %%
l=['l','e','t','a']
b=l.copy()
b.append(10)
print(l)
print(b)
# Out:
# ['l', 'e', 't', 'a']
# ['l', 'e', 't', 'a', 10]

# %%
l=[10,5,[1,3],4]
b=l.copy()      
b[2].insert(1,'py') #in sallow copy the normal sequence updated in the copied sequence will not reflected but in nested sequence it will be refleted it is considered as draw back
print(b)
print(l)
# Out:
# [10, 5, [1, 'py', 3], 4]
# [10, 5, [1, 'py', 3], 4]

# %%
l=[10,5,[1,3],4]
l.clear()
print(l)
# Out:
# []

# %%
l=['l','e','t','a']
l.sort()
print(l)
l.sort(reverse=True)
print(l)
# Out:
# ['a', 'e', 'l', 't']
# ['t', 'l', 'e', 'a']
