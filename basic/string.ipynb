# %%
s="I am from TamilNadu"
print(s.swapcase())
# Out:
# i AM FROM tAMILnADU

# %%
s="We are students of Hindusthan"
print(s.capitalize())
print(s.casefold()) #this for comparision for different string for caseless str
# Out:
# We are students of hindusthan
# we are students of hindusthan

# %%
s="kids are so small goooood"
print(s.count('a'))
print(s.count('i',2))
print(s.count('oo')) #non-overlapping
# Out:
# 2
# 0
# 2

# %%
s="What bro it's very wrong bro"
print(s.index('b'))
print(s.index("it's"))
print(s.rindex("b"))
# print(s.index('z'))#value error
# Out:
# 5
# 9
# 25

# %%
s="roses are beautiful in nature"
print(s.title())
print(s.istitle())
print(s.title().istitle())
# Out:
# Roses Are Beautiful In Nature
# False
# True

# %%
s ='Dhanush Is Good Boy '
# s='2'
print(s.lower())
print(s.islower())
print(s.lower().islower())
# Out:
# dhanush is good boy
# False
# True

# %%
s ='Dhanush Is Good Boy '
print(s.upper())
print(s.isupper())
print(s.upper().isupper())
# Out:
# DHANUSH IS GOOD BOY
# False
# True

# %%
s='Whistle Podu vetri'
print(s.find('a'))
print(s.find('w'))
print(s.find("W"))
print(s.find('i'))
print(s.rfind('i'))
# Out:
# -1
# -1
# 0
# 2
# 17

# %%
s="I don't want new bike"
print(s.split(" ",2))
print(s.split(" "))
print(s.split("n"))
# Out:
# ['I', "don't", 'want new bike']
# ['I', "don't", 'want', 'new', 'bike']
# ['I do', "'t wa", 't ', 'ew bike']

# %%
s="I don't want new \n bike"
print(s.splitlines())
print(s.splitlines(keepends=True))
# Out:
# ["I don't want new ", ' bike']
# ["I don't want new \n", ' bike']

# %%
s=";hello world"
s1='##welcome#'
print(s.strip(';'))
print(s1.strip('#'))
print(s.strip("-"))
# Out:
# hello world
# welcome
# ;hello world

# %%
s="Thalapathy"
print(s.center(2))
print(s.center(12,'-'))
print(s.center(11,'-'))#when the width of a str is even and we try to odd the center it start from left
s1='bad'
print(s1.center(4,'=')) #when the width of the str is odd and we try to even the center it start from right
# Out:
# Thalapathy
# -Thalapathy-
# -Thalapathy
# bad=

# %%
s="Vijay"
print(s.ljust(7,'-'))
print(s.rjust(6,'@'))
# Out:
# Vijay--
# @Vijay

# %%
s='TamilNadu'
print(s.partition('m'))
print(s.rpartition('m'))
print(s.partition('a'))
print(s.rpartition('a'))
# Out:
# ('Ta', 'm', 'ilNadu')
# ('Ta', 'm', 'ilNadu')
# ('T', 'a', 'milNadu')
# ('TamilN', 'a', 'du')

# %%
s="good one is the always good properties"
print(s.replace('good','very good'))
print(s.replace('good','very good',2))
print(s.replace('good','very good',3))
print(s.replace('good','very good',1))
# Out:
# very good one is the always very good properties
# very good one is the always very good properties
# very good one is the always very good properties
# very good one is the always good properties

# %%
s='10'
s1='+10'
print(s.zfill(3))
print(s1.zfill(4))
print('-1'.zfill(3))
print('py'.zfill(3))
# Out:
# 010
# +010
# -01
# 0py

# %%
s="hi, My name is {name} and I am from {place}"
print(s.format(name='dhanush',place='Tenkasi'))
d={'name':'vijay','place':'chennai'}
print(s.format_map(d))
# Out:
# hi, My name is dhanush and I am from Tenkasi
# hi, My name is vijay and I am from chennai

# %%
s="Abac"
res=s.encode()
print(res)
for i in res:
    print(i)
# Out:
# b'Abac'
# 65
# 98
# 97
# 99

# %%
s='break\n'
s1='abc233'
print(s.isidentifier())
print(s1.isidentifier())
# Out:
# False
# True

# %%
s='Dhanush'
s1='dhanush123'
s2='dhanush;'
s3=' dhanush is a boy'
s4=" "
print(s.isalpha())
print(s1.isalpha())
print(s2.isalpha())
print(s3.isspace())
print(s4.isspace())
# Out:
# True
# False
# False
# False
# True
