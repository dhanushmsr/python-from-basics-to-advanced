# %%
from functools import reduce
def more(l,s):
    return l+s
print(reduce(more,[12,10,6,3],10))
# Out:
# 41

# %%
def val(a,b):
    if a>b:
        return a
    else:
        return b
    
print(reduce(val,[20,46,12,67,32,10]))
# Out:
# 67
